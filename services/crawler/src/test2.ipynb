# %%
import sys 
sys.path.append(r"C:\Users\kionc\Projects\Taiwan_Job_Market_Analysis\services\crawler")

# %%
import json
import pandas as pd
with open("src/test.json", encoding="utf-8") as f:
    test = json.load(f)

test = pd.DataFrame(test)

# %%
# JobDetail
